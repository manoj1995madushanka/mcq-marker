# %%
from utils.rectangleDetector import detectRectangleContours, getCornerPoints
from utils.stackImages import stackImages
import cv2
import numpy as np

path = "img.png"
widthImg = 700
heightImg = 700

img = cv2.imread(path)

# resize image
img = cv2.resize(img, (widthImg, heightImg))
imgContours = img.copy()

# Preprocessing
# convert to grayscale
imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgBlur = cv2.GaussianBlur(imgGray, (5, 5), 1)
imgCanny = cv2.Canny(imgBlur, 10, 50)

# Find contours
countours, hierarchy = cv2.findContours(imgCanny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
# -1 means index and that value represent all, 10 is the thickness
cv2.drawContours(imgContours, countours, -1, (0, 255, 0), 10)
# Find rectangle contours
rectangleContours = detectRectangleContours(countours)
biggestContour = getCornerPoints(rectangleContours[0])  # because it is reverse ordered and this is answers
gradePoints = getCornerPoints(rectangleContours[1])  # this is getting grade rectangle points of the image
print(biggestContour)  # this is printing x,y coordinates of the 4 corner points of biggest rectangle

imgBlank = np.zeros_like(img)  # create blank image
imgArray = (
    [img, imgGray, imgBlur, imgCanny],
    [imgContours, imgBlank, imgBlank, imgBlank]
)
imgStacked = stackImages(0.5, imgArray, [])

cv2.imshow("Stacked Images", imgStacked)
cv2.waitKey(0)
# Out:
# Area :  0.0
# Area :  82.0
# Corner points :  8
# Area :  123.5
# Corner points :  7
# Area :  0.0
# Area :  78.5
# Corner points :  12
# Area :  0.0
# Area :  0.0
# Area :  11.5
# Area :  8.0
# Area :  6.5
# Area :  98.0
# Corner points :  9
# Area :  0.0
# Area :  125.5
# Corner points :  8
# Area :  1.0
# Area :  1.0
# Area :  0.5
# Area :  10.0
# Area :  15.5
# Area :  14.5
# Area :  26.5
# Area :  38.5
# Area :  6.5
# Area :  6.0
# Area :  332.0
# Corner points :  12
# Area :  0.5
# Area :  2.0
# Area :  12.0
# Area :  14.5
# Area :  0.0
# Area :  38.5
# Area :  11.5
# Area :  0.0
# Area :  17.5
# Area :  0.5
# Area :  426.0
# Corner points :  12
# Area :  26.5
# Area :  13.0
# Area :  12.0
# Area :  24.0
# Area :  475.5
# Corner points :  7
# Area :  480.5
# Corner points :  8
# Area :  22135.0
# Corner points :  4
# Area :  13589.5
# Corner points :  12
# Area :  103675.5
# Corner points :  4
# Area :  164.0
# Corner points :  6
# Area :  10178.5
# Corner points :  4
# Area :  0.0
# Area :  0.0
# Area :  4244.0
# Corner points :  3
# Area :  7.5
# Area :  0.0
# Area :  14.0
# Area :  0.0
# Area :  41.5
# Area :  30.5
# Area :  208.0
# Corner points :  11
# Area :  16.0
# Area :  115.5
# Corner points :  10
# Area :  99.0
# Corner points :  9
# Area :  284.0
# Corner points :  8
# Area :  19.5
# Area :  0.0
# Area :  0.0
# Area :  15.0
# Area :  0.0
# Area :  0.5
# Area :  0.0
# Area :  222.5
# Corner points :  10
# Area :  32.5
# Area :  98.5
# Corner points :  10
# Area :  7.0
# Area :  2.5
# Area :  143.0
# Corner points :  12
# Area :  19.5
# Area :  227.5
# Corner points :  8
# Area :  7.5
# Area :  15.5
# Area :  29.0
# Area :  0.0
# Area :  0.0
# Area :  15.0
# Area :  1.5
# Area :  0.0
# Area :  0.0
# [array([[[360, 433]],
#
#        [[359, 434]],
#
#        [[358, 434]],
#
#        ...,
#
#        [[363, 434]],
#
#        [[362, 434]],
#
#        [[361, 433]]], dtype=int32), array([[[236, 114]],
#
#        [[236, 115]],
#
#        [[235, 116]],
#
#        ...,
#
#        [[239, 114]],
#
#        [[238, 114]],
#
#        [[237, 114]]], dtype=int32), array([[[133, 103]],
#
#        [[132, 104]],
#
#        [[131, 105]],
#
#        ...,
#
#        [[136, 103]],
#
#        [[135, 103]],
#
#        [[134, 103]]], dtype=int32)]
# 1303
# -1
